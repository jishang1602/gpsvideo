# %% [markdown]
# <a href="https://colab.research.google.com/github/jishang1602/gpsvideo/blob/master/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Downlaod the ffmpeg build for android for video capture funcationality in the opencv/ncnn

# %%
# %cd /opt/
# !wget https://dl.google.com/android/repository/android-ndk-r20b-linux-x86_64.zip
# Out:
# /opt
# --2021-02-22 07:24:19--  https://dl.google.com/android/repository/android-ndk-r20b-linux-x86_64.zip
# Resolving dl.google.com (dl.google.com)... 74.125.142.91, 74.125.142.136, 74.125.142.93, ...
# Connecting to dl.google.com (dl.google.com)|74.125.142.91|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 859780564 (820M) [application/zip]
# Saving to: ‘android-ndk-r20b-linux-x86_64.zip’
#
# android-ndk-r20b-li 100%[===================>] 819.95M  38.3MB/s    in 22s
#
# 2021-02-22 07:24:40 (37.8 MB/s) - ‘android-ndk-r20b-linux-x86_64.zip’ saved [859780564/859780564]

# %%
# !git clone https://git.ffmpeg.org/ffmpeg.git ffmpeg
# Out:
# Cloning into 'ffmpeg'...
# remote: Counting objects: 617702, done.
# remote: Compressing objects: 100% (127246/127246), done.
# remote: Total 617702 (delta 496426), reused 609212 (delta 489196)
# Receiving objects: 100% (617702/617702), 144.93 MiB | 14.19 MiB/s, done.
# Resolving deltas: 100% (496426/496426), done.

# %%
# %cd ffmpeg
# Out:
# /opt/ffmpeg

# %%
# !git checkout release/4.3
# Out:
# Branch 'release/4.3' set up to track remote branch 'release/4.3' from 'origin'.
# Switched to a new branch 'release/4.3'

# %%
# !apt-get install unzip
# !unzip android-ndk-r20b-linux-x86_64.zip

# %%
# %cd /opt/
# !unzip android-ndk-r20b-linux-x86_64.zip

# %%
# %cd /opt/ffmpeg/
# Out:
# /opt/ffmpeg

# %%
# !mkdir -p android/armeabi-v7a

# %%
# !chmod a+x android-build.sh

# %%
# !sudo ./android-build.sh
# Out:
# Compiling FFmpeg for armv7-a
# install prefix            /opt/ffmpeg/android/armv7-a
# source path               .
# C compiler                /opt/android-ndk-r20b/toolchains/llvm/prebuilt/linux-x86_64//bin/armv7a-linux-androideabi23-clang
# C library                 bionic
# host C compiler           gcc
# host C library            glibc
# ARCH                      c (armv7-a)
# big-endian                no
# runtime cpu detection     yes
# debug symbols             yes
# strip symbols             yes
# optimize for size         no
# optimizations             yes
# static                    yes
# shared                    no
# postprocessing support    no
# network support           yes
# threading support         pthreads
# safe bitstream reader     yes
# texi2html enabled         no
# perl enabled              yes
# pod2man enabled           yes
# makeinfo enabled          no
# makeinfo supports HTML    no
#
# External libraries:
# ...

# %%
# !make
# Out:
# CC	libavdevice/alldevices.o
# CC	libavdevice/avdevice.o
# CC	libavdevice/utils.o
# AR	libavdevice/libavdevice.a
# GEN	libavdevice/libavdevice.pc
# CC	libavfilter/af_aformat.o
# CC	libavfilter/af_anull.o
# CC	libavfilter/allfilters.o
# CC	libavfilter/audio.o
# CC	libavfilter/avfilter.o
# libavfilter/avfilter.c:643:6: warning: 'child_class_next' is deprecated [-Wdeprecated-declarations]
#     .child_class_next = filter_child_class_next,
#      ^
# ./libavutil/log.h:124:5: note: 'child_class_next' has been explicitly marked deprecated here
#     attribute_deprecated
#     ^
# ./libavutil/attributes.h:100:49: note: expanded from macro 'attribute_deprecated'
# #    define attribute_deprecated __attribute__((deprecated))
#                                                 ^
# 1 warning generated.
# CC	libavfilter/avfiltergraph.o
# libavfilter/avfiltergraph.c:135:25: warning: 'resample_lavr_opts' is deprecated [-Wdeprecated-declarations]
#     av_freep(&(*graph)->resample_lavr_opts);
# ...

# %%
# !make install
# Out:
# INSTALL	install-progs-yes
# INSTALL	ffmpeg
# INSTALL	presets/libvpx-1080p50_60.ffpreset
# INSTALL	presets/libvpx-360p.ffpreset
# INSTALL	presets/libvpx-1080p.ffpreset
# INSTALL	presets/libvpx-720p50_60.ffpreset
# INSTALL	presets/libvpx-720p.ffpreset
# INSTALL	doc/ffprobe.xsd
# INSTALL	doc/examples/transcoding.c
# INSTALL	doc/examples/vaapi_transcode.c
# INSTALL	doc/examples/metadata.c
# INSTALL	doc/examples/filtering_video.c
# INSTALL	doc/examples/muxing.c
# INSTALL	doc/examples/extract_mvs.c
# INSTALL	doc/examples/encode_audio.c
# INSTALL	doc/examples/hw_decode.c
# INSTALL	doc/examples/filter_audio.c
# INSTALL	doc/examples/decode_video.c
# INSTALL	doc/examples/resampling_audio.c
# INSTALL	doc/examples/remuxing.c
# INSTALL	doc/examples/filtering_audio.c
# INSTALL	doc/examples/http_multiclient.c
# INSTALL	doc/examples/avio_reading.c
# INSTALL	doc/examples/vaapi_encode.c
# INSTALL	doc/examples/qsvdec.c
# INSTALL	doc/examples/avio_list_dir.c
# INSTALL	doc/examples/decode_audio.c
# ...

# %%
# %cd android/armeabi-v7a/
# Out:
# /opt/ffmpeg/android/armeabi-v7a

# %%
# %cd /opt/ffmpeg/
# Out:
# /opt/ffmpeg
